# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, RocCurveDisplay
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import os
import joblib # Required for saving the preprocessor

# %%
try:
    df = pd.read_csv('flight_accidents_india_synthetic.csv')
    print("Dataset loaded successfully. Info:")
    df.info()
    print("\nFirst 5 rows:")
    print(df.head())
except FileNotFoundError:
    print("Error: 'flight_accidents_india_synthetic.csv' not found. Please ensure the file is in the same directory.")
    exit() # Exit if the dataset is not found
# Out:
# Dataset loaded successfully. Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Flight_ID                       2500 non-null   object
#  1   Airline                         2500 non-null   object
#  2   Aircraft_Type                   2500 non-null   object
#  3   Aircraft_Age_Years              2500 non-null   int64
#  4   Flight_Phase                    2500 non-null   object
#  5   Departure_Airport_Code          2500 non-null   object
#  6   Arrival_Airport_Code            2500 non-null   object
#  7   Flight_Duration_Hours           2500 non-null   float64
#  8   Last_Maintenance_Hours          2500 non-null   int64
#  9   Engine_Hours_Since_Overhaul     2500 non-null   int64
#  10  Pilot_Experience_Hours          2500 non-null   int64
#  11  CoPilot_Experience_Hours        2500 non-null   int64
#  12  Number_of_Crew                  2500 non-null   int64
#  13  Total_Onboard                   2500 non-null   int64
#  14  Cargo_Weight_KG                 2500 non-null   int64
#  15  Date                            2500 non-null   object
#  16  Time_UTC                        2500 non-null   object
#  17  Season                          2500 non-null   object
#  18  Visibility_KM                   2500 non-null   float64
#  19  Wind_Speed_KNOTS                2500 non-null   int64
#  20  Wind_Direction_Degrees          2500 non-null   int64
#  21  Temperature_Celsius             2500 non-null   float64
#  22  Precipitation_MM                2500 non-null   float64
#  23  Weather_Condition               2500 non-null   object
#  24  Turbulence_Severity             1863 non-null   object
#  25  Departure_Airport_Elevation_FT  2500 non-null   int64
#  26  Arrival_Airport_Elevation_FT    2500 non-null   int64
#  27  Route_Complexity                2500 non-null   object
#  28  Air_Traffic_Density             2500 non-null   object
#  29  Accident                        2500 non-null   int64
#  30  Accident_Severity               45 non-null     object
#  31  Fatalities                      2500 non-null   int64
#  32  Injuries                        2500 non-null   int64
#  33  Aircraft_Damage                 45 non-null     object
#  34  Cause_Category                  45 non-null     object
# dtypes: float64(4), int64(15), object(16)
# memory usage: 683.7+ KB
#
# First 5 rows:
#        Flight_ID       Airline   Aircraft_Type  Aircraft_Age_Years
# 0  F202012300001        IndiGo      Boeing 737                  25  \
# 1  F202008250002      Star Air     Airbus A321                  18
# 2  F202311080003  Alliance Air  Dornier Do 228                  13
# 3  F202011300004        IndiGo          ATR 72                  13
# 4  F202412250005        FlyBig     Airbus A321                  18
#
#   Flight_Phase Departure_Airport_Code Arrival_Airport_Code
# 0         Taxi                    ATQ                  CCU  \
# 1      Takeoff                    COK                  PNQ
# 2         Taxi                    COK                  DEL
# 3      Landing                    ATQ                  COK
# 4      Takeoff                    BOM                  GOI
#
#    Flight_Duration_Hours  Last_Maintenance_Hours  Engine_Hours_Since_Overhaul
# 0                   2.93                     939                         2013  \
# 1                   2.92                     250                         2757
# 2                   4.36                    1229                         5145
# 3                   1.48                     623                          993
# 4                   4.11                     546                         6487
#
#    ...  Departure_Airport_Elevation_FT  Arrival_Airport_Elevation_FT
# 0  ...                             765                            18  \
# 1  ...                              30                          1863
# 2  ...                              30                           777
# 3  ...                             765                            30
# 4  ...                              39                           189
#
#       Route_Complexity  Air_Traffic_Density  Accident Accident_Severity
# 0   Multiple_Waypoints               Medium         0               NaN  \
# 1               Direct                 High         0               NaN
# 2  Mountainous_Terrain                  Low         0               NaN
# 3               Direct               Medium         0               NaN
# 4               Direct               Medium         0               NaN
#
#   Fatalities Injuries  Aircraft_Damage  Cause_Category
# 0          0        0              NaN             NaN
# 1          0        0              NaN             NaN
# 2          0        0              NaN             NaN
# 3          0        0              NaN             NaN
# 4          0        0              NaN             NaN
#
# [5 rows x 35 columns]

# %%
# --- 2. Prepare Data for Training ---
# Separate target variable 'Accident'
# Exclude identifier columns and other target-related columns that won't be used as features for prediction
X = df.drop(columns=['Accident', 'Accident_Severity', 'Fatalities', 'Injuries', 'Aircraft_Damage', 'Cause_Category', 'Flight_ID', 'Date', 'Time_UTC'])
y = df['Accident']

# %%
# Identify numerical and categorical columns for preprocessing
numerical_cols = X.select_dtypes(include=np.number).columns.tolist()
categorical_cols = X.select_dtypes(include='object').columns.tolist()

# %%
print(f"\nNumerical columns identified: {numerical_cols}")
print(f"Categorical columns identified: {categorical_cols}")
# Out:
# Numerical columns identified: ['Aircraft_Age_Years', 'Flight_Duration_Hours', 'Last_Maintenance_Hours', 'Engine_Hours_Since_Overhaul', 'Pilot_Experience_Hours', 'CoPilot_Experience_Hours', 'Number_of_Crew', 'Total_Onboard', 'Cargo_Weight_KG', 'Visibility_KM', 'Wind_Speed_KNOTS', 'Wind_Direction_Degrees', 'Temperature_Celsius', 'Precipitation_MM', 'Departure_Airport_Elevation_FT', 'Arrival_Airport_Elevation_FT']
# Categorical columns identified: ['Airline', 'Aircraft_Type', 'Flight_Phase', 'Departure_Airport_Code', 'Arrival_Airport_Code', 'Season', 'Weather_Condition', 'Turbulence_Severity', 'Route_Complexity', 'Air_Traffic_Density']

# %%
numerical_transformer = StandardScaler()

# OneHotEncoder for categorical features (handle_unknown='ignore' for unseen categories in new data)
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# Fit and transform the training data
# This step applies scaling and one-hot encoding
X_processed = preprocessor.fit_transform(X)

print(f"\nShape of preprocessed data (X_processed): {X_processed.shape}")
# Out:
# Shape of preprocessed data (X_processed): (2500, 81)

# %%
# Reshape X_processed for Conv1D input: (samples, timesteps, features)
# For tabular data with Conv1D, each feature is treated as a timestep, and we add a channel dimension of 1.
X_processed = X_processed.reshape(X_processed.shape[0], X_processed.shape[1], 1)

print(f"Reshaped X_processed for Conv1D input: {X_processed.shape}")
# Out:
# Reshaped X_processed for Conv1D input: (2500, 81, 1)

# %%
# Split the dataset into training and testing sets
# stratify=y ensures that the proportion of 'Accident' (1s) is the same in train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2, random_state=42, stratify=y)

print(f"\nTraining data shape: {X_train.shape}")
print(f"Testing data shape: {X_test.shape}")
# Out:
# Training data shape: (2000, 81, 1)
# Testing data shape: (500, 81, 1)

# %%
# --- 4. Define and Compile the CNN Model ---
model = Sequential([
    # First Convolutional Layer
    Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)),
    MaxPooling1D(pool_size=2), # Reduces dimensionality

    # Second Convolutional Layer
    Conv1D(filters=128, kernel_size=3, activation='relu'),
    MaxPooling1D(pool_size=2),

    # Flatten the output for the Dense layers
    Flatten(),

    # Fully Connected (Dense) Layers
    Dense(128, activation='relu'),
    Dropout(0.5), # Dropout for regularization to prevent overfitting

    # Output layer for binary classification
    Dense(1, activation='sigmoid') # Sigmoid activation for probabilities between 0 and 1
])

# Compile the model
# Adam optimizer is a good default choice
# binary_crossentropy for binary classification problems
# metrics=['accuracy'] to monitor performance during training
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

print("\nCNN Model Summary:")
model.summary()
# Out:
# CNN Model Summary:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 79, 64)            256
#
#  max_pooling1d (MaxPooling1  (None, 39, 64)            0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 37, 128)           24704
#
#  max_pooling1d_1 (MaxPoolin  (None, 18, 128)           0
#  g1D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 128)               295040
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 320129 (1.22 MB)
# Trainable params: 320129 (1.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# --- 5. Train the Model ---
print("\nStarting model training...")
history = model.fit(
    X_train, y_train,
    epochs=50,          # Number of training iterations
    batch_size=32,      # Number of samples per gradient update
    validation_split=0.2, # Use 20% of training data for validation during training
    verbose=1           # Show training progress
)
# Out:
# Starting model training...
# Epoch 1/50
# 50/50 [==============================] - 2s 11ms/step - loss: 0.1363 - accuracy: 0.9737 - val_loss: 0.1206 - val_accuracy: 0.9800
# Epoch 2/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0951 - accuracy: 0.9825 - val_loss: 0.1076 - val_accuracy: 0.9800
# Epoch 3/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0925 - accuracy: 0.9825 - val_loss: 0.1062 - val_accuracy: 0.9800
# Epoch 4/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0911 - accuracy: 0.9825 - val_loss: 0.1157 - val_accuracy: 0.9800
# Epoch 5/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0919 - accuracy: 0.9825 - val_loss: 0.1122 - val_accuracy: 0.9800
# Epoch 6/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0850 - accuracy: 0.9825 - val_loss: 0.1124 - val_accuracy: 0.9800
# Epoch 7/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0802 - accuracy: 0.9825 - val_loss: 0.1161 - val_accuracy: 0.9800
# Epoch 8/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0807 - accuracy: 0.9825 - val_loss: 0.1175 - val_accuracy: 0.9800
# Epoch 9/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0701 - accuracy: 0.9825 - val_loss: 0.1252 - val_accuracy: 0.9800
# Epoch 10/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0688 - accuracy: 0.9825 - val_loss: 0.1431 - val_accuracy: 0.9800
# Epoch 11/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0636 - accuracy: 0.9825 - val_loss: 0.1502 - val_accuracy: 0.9800
# Epoch 12/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0592 - accuracy: 0.9825 - val_loss: 0.1400 - val_accuracy: 0.9800
# Epoch 13/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0530 - accuracy: 0.9825 - val_loss: 0.1576 - val_accuracy: 0.9800
# Epoch 14/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0462 - accuracy: 0.9825 - val_loss: 0.1610 - val_accuracy: 0.9800
# Epoch 15/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0461 - accuracy: 0.9825 - val_loss: 0.1756 - val_accuracy: 0.9800
# Epoch 16/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0392 - accuracy: 0.9825 - val_loss: 0.1826 - val_accuracy: 0.9800
# Epoch 17/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0332 - accuracy: 0.9825 - val_loss: 0.1922 - val_accuracy: 0.9800
# Epoch 18/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0303 - accuracy: 0.9825 - val_loss: 0.2137 - val_accuracy: 0.9800
# Epoch 19/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0259 - accuracy: 0.9825 - val_loss: 0.2258 - val_accuracy: 0.9800
# Epoch 20/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0221 - accuracy: 0.9831 - val_loss: 0.2236 - val_accuracy: 0.9800
# Epoch 21/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0213 - accuracy: 0.9825 - val_loss: 0.2393 - val_accuracy: 0.9800
# Epoch 22/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0181 - accuracy: 0.9862 - val_loss: 0.2969 - val_accuracy: 0.9800
# Epoch 23/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0172 - accuracy: 0.9862 - val_loss: 0.2956 - val_accuracy: 0.9800
# Epoch 24/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0150 - accuracy: 0.9894 - val_loss: 0.2840 - val_accuracy: 0.9800
# Epoch 25/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0145 - accuracy: 0.9925 - val_loss: 0.3084 - val_accuracy: 0.9800
# Epoch 26/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0136 - accuracy: 0.9950 - val_loss: 0.3114 - val_accuracy: 0.9800
# Epoch 27/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0123 - accuracy: 0.9981 - val_loss: 0.3193 - val_accuracy: 0.9800
# Epoch 28/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0120 - accuracy: 0.9987 - val_loss: 0.3182 - val_accuracy: 0.9800
# Epoch 29/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0117 - accuracy: 0.9987 - val_loss: 0.3334 - val_accuracy: 0.9800
# Epoch 30/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0116 - accuracy: 0.9994 - val_loss: 0.3508 - val_accuracy: 0.9800
# Epoch 31/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.3617 - val_accuracy: 0.9800
# Epoch 32/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.3532 - val_accuracy: 0.9800
# Epoch 33/50
# 50/50 [==============================] - 1s 11ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.3752 - val_accuracy: 0.9800
# Epoch 34/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.3675 - val_accuracy: 0.9800
# Epoch 35/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.3932 - val_accuracy: 0.9800
# Epoch 36/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.3847 - val_accuracy: 0.9800
# Epoch 37/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.3815 - val_accuracy: 0.9800
# Epoch 38/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.3919 - val_accuracy: 0.9800
# Epoch 39/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.3951 - val_accuracy: 0.9800
# Epoch 40/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.4068 - val_accuracy: 0.9800
# Epoch 41/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.3870 - val_accuracy: 0.9800
# Epoch 42/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.3976 - val_accuracy: 0.9800
# Epoch 43/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.3923 - val_accuracy: 0.9800
# Epoch 44/50
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.4034 - val_accuracy: 0.9800
# Epoch 45/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.4078 - val_accuracy: 0.9800
# Epoch 46/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.4332 - val_accuracy: 0.9800
# Epoch 47/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.4274 - val_accuracy: 0.9800
# Epoch 48/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.4115 - val_accuracy: 0.9800
# Epoch 49/50
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.4263 - val_accuracy: 0.9800
# Epoch 50/50
# 50/50 [==============================] - 0s 9ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.4284 - val_accuracy: 0.9800

# %%
# --- 6. Evaluate the Model ---
print("\nEvaluating the model on the test set...")
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Evaluating the model on the test set...
# Test Loss: 0.3337
# Test Accuracy: 0.9820

# %%
# --- 7. Save the Trained Model and Preprocessor ---
# Save the Keras model in HDF5 format
model_filename = 'flight_accident_cnn_model.h5'
model.save(model_filename)
print(f"\nTrained CNN model saved as '{model_filename}'")
# Out:
# Trained CNN model saved as 'flight_accident_cnn_model.h5'
# C:\Users\User\anaconda3\envs\Project\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Save the preprocessor using joblib
# This is crucial because new data must be transformed using the exact same scaling and encoding
preprocessor_filename = 'preprocessor.pkl'
joblib.dump(preprocessor, preprocessor_filename)
print(f"Preprocessor saved as '{preprocessor_filename}'")

print("\nTraining and file creation process complete.")
# Out:
# Preprocessor saved as 'preprocessor.pkl'
#
# Training and file creation process complete.

# %%
# --- 8. Visualizations ---

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.grid(True)

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
y_pred_proba = model.predict(X_test)
# Convert probabilities to binary predictions (0 or 1)
y_pred = (y_pred_proba > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Predicted No Accident', 'Predicted Accident'],
            yticklabels=['Actual No Accident', 'Actual Accident'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 16/16 [==============================] - 0s 2ms/step

# %%
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       491
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.98       500
#    macro avg       0.49      0.50      0.50       500
# weighted avg       0.96      0.98      0.97       500
# C:\Users\User\anaconda3\envs\Project\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\User\anaconda3\envs\Project\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\User\anaconda3\envs\Project\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
# Scatter Chart for two numerical features, colored by target
# Using original features before preprocessing for better interpretability
# Check if these columns exist in the original DataFrame
if 'Aircraft_Age_Years' in df.columns and 'Flight_Hours_Last_Service' in df.columns:
    plt.figure(figsize=(10, 7))
    sns.scatterplot(x='Aircraft_Age_Years', y='Flight_Hours_Last_Service', hue='Accident', data=df, palette='viridis', alpha=0.7)
    plt.title('Aircraft Age vs. Flight Hours Last Service by Accident Status')
    plt.xlabel('Aircraft Age (Years)')
    plt.ylabel('Flight Hours Since Last Service')
    plt.grid(True)
    plt.show()
else:
    print("\n'Aircraft_Age_Years' or 'Flight_Hours_Last_Service' not found for scatter plot.")

# Feature Bar Charts for categorical features
# Using original features before preprocessing
plt.figure(figsize=(15, 6))
# Out:
# 'Aircraft_Age_Years' or 'Flight_Hours_Last_Service' not found for scatter plot.

# %%
if 'Aircraft_Type' in df.columns:
    plt.subplot(1, 2, 1)
    sns.countplot(y='Aircraft_Type', data=df, order=df['Aircraft_Type'].value_counts().index, palette='coolwarm')
    plt.title('Distribution of Aircraft Types')
    plt.xlabel('Count')
    plt.ylabel('Aircraft Type')
else:
    print("\n'Aircraft_Type' column not found for bar chart.")

if 'Phase_of_Flight' in df.columns:
    plt.subplot(1, 2, 2)
    sns.countplot(y='Phase_of_Flight', data=df, order=df['Phase_of_Flight'].value_counts().index, palette='viridis')
    plt.title('Distribution of Phase of Flight')
    plt.xlabel('Count')
    plt.ylabel('Phase of Flight')
else:
    print("\n'Phase_of_Flight' column not found for bar chart.")

plt.tight_layout()
plt.show()
# Out:
# 'Phase_of_Flight' column not found for bar chart.
